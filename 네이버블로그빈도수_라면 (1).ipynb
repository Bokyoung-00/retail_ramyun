# %%
import pandas as pd

# %%
#!pip install xlrd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

fname=fm.FontProperties(fname='NanumGothic.ttf').get_name()
print(fname)
mpl.rc('font',family=fname)
plt.rcParams['font.family'] = fname
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-95d899fd5e56> in <module>()
#       4 import matplotlib.font_manager as fm
#       5
# ----> 6 fname=fm.FontProperties(fname='NanumGothic.ttf').get_name()
#       7 print(fname)
#       8 mpl.rc('font',family=fname)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/font_manager.py in get_name(self)
#     687         Return the name of the font that best matches the font properties.
#     688         """
# --> 689         return get_font(findfont(self)).family_name
#     690
#     691     def get_style(self):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/font_manager.py in get_font(filename, hinting_factor)
#    1327         hinting_factor = rcParams['text.hinting_factor']
#    1328     return _get_font(os.fspath(filename), hinting_factor,
# ...

# %% [markdown]
# ## 트러플 짜파게티 (2019년 7월)

# %%
naver=pd.read_excel('C:/Users/ASIA_08/truffle3.xlsx')

# %%
naver.head()
# Out:
#            날짜         빈도
# 0  2019-07-01  100.00000
# 1  2019-08-01   29.94732
# 2  2019-09-01   15.75298
# 3  2019-10-01    9.24253
# 4  2019-11-01   10.12397

# %%
lists = list(naver['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
def make_graph2(X):
  copy_X = X.copy()
  copy_X.columns = ['date','number of searches']
  date_list = list(copy_X['date'])
  new_list = []
  for item in date_list:
    itemstr = str(item)
    a = itemstr.split('-')[0]+itemstr.split('-')[1]
    new_list.append(a[0:6])
  copy_X['date'] = new_list

  new_X = copy_X.groupby(['date']).sum()
  rearr_X = new_X.reset_index()
  final_X = rearr_X.iloc[1:12,]

  plt.figure(figsize=(10,5))
  sns.set(style="whitegrid")
  sns.lineplot(x='date',y='number of searches',data=final_X,palette='r')
  sns.barplot(x='date', y='number of searches',palette='ch:.25',data=final_X)
  plt.show()

# %%
make_graph2(naver)

# %% [markdown]
# ## 1 마라탕면 (삼양은 2019.7 출시, CJ는 2019.11 출시)

# %%
mara = pd.read_excel('C:/Users/ASIA_08/maratang.xlsx')

# %%
mara.head()
# Out:
#            날짜         빈도
# 0  2019-07-01  100.00000
# 1  2019-08-01   92.36225
# 2  2019-09-01   75.18211
# 3  2019-10-01   55.99686
# 4  2019-11-01   39.82002

# %%
lists = list(mara['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
make_graph2(mara)

# %% [markdown]
# ## 2 얼큰한 토마토라면 (2017년 12월 출시)

# %%
tomato = pd.read_excel('C:/Users/ASIA_08/tomato.xlsx')

# %%
tomato.head()
# Out:
#            날짜         빈도
# 0  2017-12-01   80.27210
# 1  2018-01-01  100.00000
# 2  2018-02-01   66.32653
# 3  2018-03-01   83.02721
# 4  2018-04-01   61.93877

# %%
lists = list(tomato['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# 201904
# 201905
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
make_graph2(tomato)

# %% [markdown]
# ## 3 미역초비빔면 (2019.04 출시)

# %%
seaweed = pd.read_excel('C:/Users/ASIA_08/seaweed.xlsx')

# %%
seaweed.head()
# Out:
#            날짜         빈도
# 0  2019-04-01   47.61904
# 1  2019-05-01  100.00000
# 2  2019-06-01   53.62394
# 3  2019-07-01   44.06512
# 4  2019-08-01   39.95098

# %%
lists = list(seaweed['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 201904
# 201905
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
make_graph2(seaweed)

# %% [markdown]
# ## 4 진짬뽕 (2015년 10월 출시)

# %%
jjampong = pd.read_excel('C:/Users/ASIA_08/jjampong.xlsx')

# %%
jjampong.head()
# Out:
#           날짜         빈도
# 0 2016-01-01  100.00000
# 1 2016-02-01   56.10805
# 2 2016-03-01   36.43136
# 3 2016-04-01   18.86604
# 4 2016-05-01   11.95554

# %%
lists = list(jjampong['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 201601
# 201602
# 201603
# 201604
# 201605
# 201606
# 201607
# 201608
# 201609
# 201610
# 201611
# 201612
# 201701
# 201702
# 201703
# 201704
# 201705
# 201706
# 201707
# 201708
# 201709
# 201710
# 201711
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# 201904
# 201905
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
make_graph2(jjampong)

# %% [markdown]
# ## 5 마라불닭볶음면 (2017.7 출시)

# %%
buldak = pd.read_excel('C:/Users/ASIA_08/buldak.xlsx')

# %%
buldak.head()
# Out:
#            날짜         빈도
# 0  2017-07-01    0.79930
# 1  2017-08-01  100.00000
# 2  2017-09-01   24.48063
# 3  2017-10-01   19.89192
# 4  2017-11-01   30.59591

# %%
lists = list(buldak['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 201707
# 201708
# 201709
# 201710
# 201711
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# 201904
# 201905
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
make_graph2(buldak)

# %% [markdown]
# ## 6 짱구허니시나몬볶음 (2019년 5월)

# %%
cinamonmeun = pd.read_excel('C:/Users/ASIA_08/cinamonmeun.xlsx')

# %%
cinamonmeun.head()
# Out:
#            날짜         빈도
# 0  2019-05-01  100.00000
# 1  2019-06-01   20.96774
# 2  2019-07-01    0.00000
# 3  2019-08-01    8.06451
# 4  2019-09-01    8.06451

# %%
lists = list(cinamonmeun['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 201905
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
make_graph2(cinamonmeun)

# %% [markdown]
# ## 7 오모리김치찌개라면 (2016년 2월 출시) GS25 PB상품

# %%
omori = pd.read_excel('C:/Users/ASIA_08/omori.xlsx')

# %%
omori.head()
# Out:
#            날짜         빈도
# 0  2016-01-01   94.11273
# 1  2016-02-01   75.44553
# 2  2016-03-01   89.95317
# 3  2016-04-01  100.00000
# 4  2016-05-01   80.95168

# %%
lists = list(omori['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 201601
# 201602
# 201603
# 201604
# 201605
# 201606
# 201607
# 201608
# 201609
# 201610
# 201611
# 201612
# 201701
# 201702
# 201703
# 201704
# 201705
# 201706
# 201707
# 201708
# 201709
# 201710
# 201711
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# 201904
# 201905
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
make_graph2(omori)

# %% [markdown]
# ## 8 이가 총각 김치 라면 (2017.10 출시)

# %%
chongakchi = pd.read_excel('C:/Users/ASIA_08/chongakchi.xlsx')

# %%
chongakchi.head()
# Out:
#            날짜         빈도
# 0  2017-10-01  100.00000
# 1  2017-11-01    0.00000
# 2  2017-12-01    0.00000
# 3  2018-01-01   46.66666
# 4  2018-02-01    0.00000

# %%
lists = list(chongakchi['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 201710
# 201711
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# 201904
# 201905
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
make_graph2(chongakchi)

# %% [markdown]
# ## 9 쇠고기 미역국라면 (2018년 9월 출시)

# %%
seaweed_otugi = pd.read_excel('C:/Users/ASIA_08/seaweed_otugi.xlsx')

# %%
seaweed_otugi.head()
# Out:
#            날짜         빈도
# 0  2018-09-01  100.00000
# 1  2018-10-01   82.02620
# 2  2018-11-01   72.27248
# 3  2018-12-01   57.91441
# 4  2019-01-01   36.20960

# %%
lists = list(seaweed_otugi['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# 201904
# 201905
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
make_graph2(seaweed_otugi)

# %% [markdown]
# ## 10 감자탕면 (2017.9 출시)

# %%
potatang = pd.read_excel('C:/Users/ASIA_08/potatang.xlsx')

# %%
potatang.head()
# Out:
#            날짜         빈도
# 0  2017-08-01   18.61338
# 1  2017-09-01  100.00000
# 2  2017-10-01   53.19705
# 3  2017-11-01   24.97114
# 4  2017-12-01   11.17311

# %%
lists = list(potatang['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 201708
# 201709
# 201710
# 201711
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# 201904
# 201905
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
make_graph2(potatang)

# %% [markdown]
# ## 11 참치마요비빔면 (2017년 4월 출시)

# %%
chamchimayo = pd.read_excel('C:/Users/ASIA_08/chamchimayo.xlsx')

# %%
chamchimayo.head()
# Out:
#            날짜         빈도
# 0  2017-04-01   15.52371
# 1  2017-05-01  100.00000
# 2  2017-06-01   54.28086
# 3  2017-07-01   36.28592
# 4  2017-08-01   27.26552

# %%
lists = list(chamchimayo['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 201704
# 201705
# 201706
# 201707
# 201708
# 201709
# 201710
# 201711
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# 201904
# 201905
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
make_graph2(chamchimayo)

# %% [markdown]
# ## 12 별뽀빠이 야끼소바 (2019.06 출시)

# %%
popei = pd.read_excel('C:/Users/ASIA_08/popei.xlsx')

# %%
popei.head()
# Out:
#            날짜         빈도
# 0  2019-06-01  100.00000
# 1  2019-07-01   60.31984
# 2  2019-08-01   60.94452
# 3  2019-09-01   29.38530
# 4  2019-10-01   10.59470

# %%
lists = list(popei['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
make_graph2(popei)

# %% [markdown]
# ## 13 민생라면 (2018.10 출시) 이마트 PB상품

# %%
minsaeng = pd.read_excel('C:/Users/ASIA_08/minsaeng.xlsx')

# %%
minsaeng.head()
# Out:
#            날짜         빈도
# 0  2018-10-01    4.71373
# 1  2018-11-01   23.62677
# 2  2018-12-01   17.35953
# 3  2019-01-01    9.00643
# 4  2019-02-01  100.00000

# %%
lists = list(minsaeng['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# 201904
# 201905
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
make_graph2(minsaeng)

# %% [markdown]
# ## 14 삼계탕면 (2019.06 출시)

# %%
samgaetang = pd.read_excel('C:/Users/ASIA_08/samgaetang.xlsx')

# %%
samgaetang.head()
# Out:
#            날짜         빈도
# 0  2019-06-01   12.79942
# 1  2019-07-01  100.00000
# 2  2019-08-01   26.17123
# 3  2019-09-01   17.19095
# 4  2019-10-01   10.56277

# %%
lists = list(samgaetang['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
make_graph2(samgaetang)

# %% [markdown]
# ## 15 농심 야채라면 (2016.3 출시)

# %%
yachae = pd.read_excel('C:/Users/ASIA_08/yachae.xlsx')

# %%
yachae.head()
# Out:
#            날짜        빈도
# 0  2016-01-01  13.19758
# 1  2016-02-01  11.99095
# 2  2016-03-01  17.72247
# 3  2016-04-01  11.08597
# 4  2016-05-01  11.38763

# %%
lists = list(yachae['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 201601
# 201602
# 201603
# 201604
# 201605
# 201606
# 201607
# 201608
# 201609
# 201610
# 201611
# 201612
# 201701
# 201702
# 201703
# 201704
# 201705
# 201706
# 201707
# 201708
# 201709
# 201710
# 201711
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# 201904
# 201905
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
make_graph2(yachae)

# %% [markdown]
# ## 16 봉골라면 (2020년 2월)

# %%
bongol = pd.read_excel('C:/Users/ASIA_08/bongol.xlsx')

# %%
bongol.head()
# Out:
#            날짜         빈도
# 0  2020-02-01   80.60249
# 1  2020-03-01   55.42493
# 2  2020-04-01  100.00000
# 3  2020-05-01   59.22116
# 4  2020-06-01   47.78349

# %%
lists = list(bongol['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
make_graph2(bongol)

# %% [markdown]
# ## 17 와사마요 볶음면 (2017.06 출시)

# %%
wasamayo = pd.read_excel('C:/Users/ASIA_08/wasamayo.xlsx')

# %%
wasamayo.head()
# Out:
#            날짜         빈도
# 0  2017-06-01   62.36600
# 1  2017-07-01  100.00000
# 2  2017-08-01   49.17559
# 3  2017-09-01   24.18881
# 4  2017-10-01   15.50257

# %%
lists = list(wasamayo['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 201706
# 201707
# 201708
# 201709
# 201710
# 201711
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# 201904
# 201905
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
make_graph2(wasamayo)

# %% [markdown]
# ## 18 리얼치즈라면 (2017.09 출시)

# %%
realcheese = pd.read_excel('C:/Users/ASIA_08/realcheese.xlsx')

# %%
realcheese.head()
# Out:
#            날짜         빈도
# 0  2017-09-01   64.82544
# 1  2017-10-01  100.00000
# 2  2017-11-01   75.94665
# 3  2017-12-01   56.53425
# 4  2018-01-01   41.96169

# %%
lists = list(realcheese['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 201709
# 201710
# 201711
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# 201904
# 201905
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
make_graph2(realcheese)

# %% [markdown]
# ## 19 쌈장라면 (2017.12 출시)

# %%
ssamjang = pd.read_excel('C:/Users/ASIA_08/ssamjang.xlsx')

# %%
ssamjang.head()
# Out:
#            날짜         빈도
# 0  2017-12-01  100.00000
# 1  2018-01-01   33.57624
# 2  2018-02-01   16.52395
# 3  2018-03-01   16.74257
# 4  2018-04-01   13.90052

# %%
lists = list(ssamjang['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# 201904
# 201905
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
make_graph2(ssamjang)

# %% [markdown]
# ## 20 부산어묵탕면 (2017.09 출시) 세븐일레븐 PB상품

# %%
busanomuk = pd.read_excel('C:/Users/ASIA_08/busanomuk.xlsx')

# %%
busanomuk.head()
# Out:
#            날짜         빈도
# 0  2017-09-01  100.00000
# 1  2017-10-01    0.00000
# 2  2017-11-01   47.05882
# 3  2017-12-01    0.00000
# 4  2018-01-01    0.00000

# %%
lists = list(busanomuk['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 201709
# 201710
# 201711
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# 201904
# 201905
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
make_graph2(busanomuk)

# %% [markdown]
# ## 21 삼양 국민라면 (2019.06 출시)

# %%
koongmin = pd.read_excel('C:/Users/ASIA_08/koongmin.xlsx')

# %%
koongmin.head()
# Out:
#            날짜         빈도
# 0  2019-06-01  100.00000
# 1  2019-07-01   50.96322
# 2  2019-08-01   80.22961
# 3  2019-09-01   43.99688
# 4  2019-10-01   62.05487

# %%
lists = list(koongmin['날짜'])
for item in lists:
    itemstr = str(item)
    a= itemstr.split('-')[0]+itemstr.split('-')[1]
    print(a)
# Out:
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911
# 201912
# 202001
# 202002
# 202003
# 202004
# 202005
# 202006
# 202007
# 202008

# %%
make_graph2(koongmin)

# %% [markdown]
# ## 22 제주마늘라면 (2020.8 출시) CU PB상품

# %%
garlicramen = pd.read_excel('C:/Users/ASIA_08/garlicramen.xlsx')

# %%
garlicramen.head()
# Out:
#            날짜        빈도수
# 0  2020-08-24   65.16129
# 1  2020-08-31  100.00000
# 2  2020-09-07   91.39784
# 3  2020-09-14   84.30107
# 4  2020-09-21   83.22580

# %%
lists = list(garlicramen['날짜'])
lists2 = str(lists)

# %%
def make_graph2(X):
    copy_X = X.copy()
    copy_X.columns = ['date','number of searches']
    date_list = list(copy_X['date'])
    new_list = []
  
    for item in date_list:
        itemstr = str(item)
    
    a = itemstr.split('-')[0]+itemstr.split('-')[1]
    new_list.append(a[0:9])
    copy_X['date'] = new_list

    new_X = copy_X.groupby(['date']).sum()
    rearr_X = new_X.reset_index()
    final_X = rearr_X.iloc[1:12,]

    plt.figure(figsize=(10,5))
    sns.set(style="whitegrid")
    sns.lineplot(x='date',y='number of searches',data=final_X,palette='r')
    sns.barplot(x='date', y='number of searches',palette='ch:.25',data=final_X)
    plt.show()

# %% [markdown]
# def make_graph3(X):
#     copy_X = X.copy()
#     copy_X.columns = ['date','number of searches']
#     date_list = list(copy_X['date'])
#     copy_X['date'] = new_list
#     new_X = copy_X.groupby(['date']).sum()
#     rearr_X = new_X.reset_index()
#     final_X = rearr_X.iloc[1:12,]
#
#     plt.figure(figsize=(10,5))
#     sns.set(style="whitegrid")
#     sns.lineplot(x='date',y='number of searches',data=final_X,palette='r')
#     sns.barplot(x='date', y='number of searches',palette='ch:.25',data=final_X)
#     plt.show()

# %%
make_graph3(garlicramen)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-243-49dbd775e75e> in <module>
# ----> 1 make_graph3(garlicramen)
#
# <ipython-input-238-644c7939c88c> in make_graph3(X)
#       3     copy_X.columns = ['date','number of searches']
#       4     date_list = list(copy_X['date'])
# ----> 5     copy_X['date'] = new_list
#       6     new_X = copy_X.groupby(['date']).sum()
#       7     rearr_X = new_X.reset_index()
#
# NameError: name 'new_list' is not defined

# %% [markdown]
# ## 23 까르보불닭볶음면 (2017.12 출시)

# %%
carbobuldak =
